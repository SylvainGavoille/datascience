# %%
import pandas as pd

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'keyword_stat.csv', 'Untitled.ipynb']

# %%
df = pd.read_csv('keyword_stat.csv',sep=";")

# %%
df.head(20)
# Out:
#                                             keyword target   bid  average_cpc  \
# 0                            accumulateur chauffage  EXACT  0.50     0.522692
# 1                      radiateur aluminium vertical  EXACT  0.59     0.768000
# 2           +radiateur +electrique +vertical +2000w  BROAD  0.30     0.000000
# 3                                radiateur souflant  EXACT  0.24     0.560000
# 4                    +chauffage +radiant +rayonnant  BROAD  0.60     0.460000
# 5                        radiateur fonte electrique  EXACT  0.42     0.596667
# 6                 +bricorama +chauffage +electrique  BROAD  0.50     0.783333
# 7                      +radiateur +pierre +de +lave  BROAD  0.74     0.665076
# 8                    +corp +de +chauffe +electrique  BROAD  0.32     0.797143
# 9                      changer radiateur electrique  EXACT  0.51     0.505455
# 10                     radiateur a inertie pas cher  EXACT  0.24     0.900000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1723 entries, 0 to 1722
# Data columns (total 11 columns):
# keyword        1723 non-null object
# target         1723 non-null object
# bid            1723 non-null float64
# average_cpc    1723 non-null float64
# clicks         1723 non-null float64
# cost           1723 non-null float64
# cpa            1723 non-null float64
# conversions    1723 non-null float64
# hits           1723 non-null float64
# ctr            1723 non-null float64
# position       1723 non-null float64
# dtypes: float64(9), object(2)
# memory usage: 148.1+ KB
